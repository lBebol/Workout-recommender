# %% [markdown]
# # K-Nearest Neighbors (KNN) Model
#
# **Deliverable 03** - Model 1
#
# **Author:** Abdelrahman Yasser Hassan Zaky
# **ID:** 231000102
# **University:** Faculty of ITCS, Nile University

# %% [markdown]
# ## Step 1: Load Processed Data
# Load from: `../data/processed_data.pkl`

# %% [markdown]
# ## Step 2: Implement KNN
# - Test K values 1-20
# - Find optimal K

# %% [markdown]
# ## Step 3: Train Model with Optimal K

# %% [markdown]
# ## Step 4: Evaluate
# - Accuracy, Precision, Recall, F1
# - Confusion Matrix

# %% [markdown]
# ## Step 5: Save Model
# Save to: `../data/knn_model.pkl`
