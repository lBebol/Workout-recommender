# %% [markdown]
# # Recommendation Engine
#
# **Deliverable 04** - Part 2
#
# **Author:** Abdelrahman Yasser Hassan Zaky
# **ID:** 231000102

# %% [markdown]
# ## Step 1: Load Best Model & Label Encoders

# %% [markdown]
# ## Step 2: Create User Input Function

# %% [markdown]
# ## Step 3: Build Recommendation Algorithm

# %% [markdown]
# ## Step 4: Test with Example Users
# - Beginner, Cardio, Bodyweight
# - Intermediate, Strength, Full Gym
# - Advanced, Hybrid, Home Gym

# %% [markdown]
# ## Step 5: Save Recommendation Engine
